# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read the image
image = cv2.imread("Screenshot 2024-01-27 at 4.21.41 PM.png", cv2.IMREAD_GRAYSCALE)

# Apply Gaussian blur to reduce noise and improve edge detection
blurred = cv2.GaussianBlur(image, (5, 5), 0)

# Apply Otsu's thresholding to get a binary mask
_, mask = cv2.threshold(blurred, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Apply Canny edge detector to the binary mask
edges = cv2.Canny(mask, 50, 160)

# Create a mask where edges are white and the rest is black
final_mask = np.zeros_like(edges)
final_mask[edges > 0] = 255

# Invert the mask
inverse_mask = cv2.bitwise_not(final_mask)

# Apply the mask to the original image
result = cv2.bitwise_and(image, image, mask=inverse_mask)

# Display the original image, Otsu's thresholding result, edges, and the final result
plt.subplot(141), plt.imshow(image, cmap='gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])

plt.subplot(142), plt.imshow(mask, cmap='gray')
plt.title('Otsu\'s Thresholding'), plt.xticks([]), plt.yticks([])

plt.subplot(143), plt.imshow(edges, cmap='gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.subplot(144), plt.imshow(result, cmap='gray')
plt.title('Result Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
ret,thresh1 = cv2.threshold(result, 120, 255, cv2.THRESH_BINARY)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read the image
image = thresh1

# Apply Gaussian blur to reduce noise and improve edge detection
blurred = cv2.GaussianBlur(image, (5, 5), 0)

# Apply Otsu's thresholding to get a binary mask
_, mask = cv2.threshold(blurred, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Apply Canny edge detector to the binary mask
edges = cv2.Canny(mask, 50, 150)

# Create a mask where edges are white and the rest is black
final_mask = np.zeros_like(edges)
final_mask[edges > 0] = 255

# Invert the mask
inverse_mask = cv2.bitwise_not(final_mask)

# Apply the mask to the original image
result = cv2.bitwise_and(image, image, mask=inverse_mask)

# Display the original image, Otsu's thresholding result, edges, and the final result
plt.subplot(141), plt.imshow(image, cmap='gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])

plt.subplot(142), plt.imshow(mask, cmap='gray')
plt.title('Otsu\'s Thresholding'), plt.xticks([]), plt.yticks([])

plt.subplot(143), plt.imshow(edges, cmap='gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.subplot(144), plt.imshow(result, cmap='gray')
plt.title('Result Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read the binary image

# Threshold the image to ensure it's binary
binary_image = result

# Invert the binary image
inverted_image = cv2.bitwise_not(binary_image)

# Create a kernel for dilation
kernel = np.ones((3, 3), np.uint8)

# Dilate the inverted image to fill white holes in the black regions
filled_image_1 = cv2.dilate(inverted_image, kernel, iterations=1)

# Invert the result back to get the final filled image
filled_image_1 = cv2.bitwise_not(filled_image_1)

# Display the original, inverted, and filled images
plt.subplot(131), plt.imshow(binary_image, cmap='gray')
plt.title('Original Binary Image'), plt.xticks([]), plt.yticks([])

plt.subplot(132), plt.imshow(inverted_image, cmap='gray')
plt.title('Inverted Image'), plt.xticks([]), plt.yticks([])

plt.subplot(133), plt.imshow(filled_image_1, cmap='gray')
plt.title('Filled Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read the binary image

# Threshold the image to ensure it's binary
binary_image = filled_image_1

# Invert the binary image
inverted_image = cv2.bitwise_not(binary_image)

# Create a kernel for dilation
kernel = np.ones((3, 3), np.uint8)

# Dilate the inverted image to fill white holes in the black regions
filled_image_1 = cv2.dilate(inverted_image, kernel, iterations=1)

# Invert the result back to get the final filled image
filled_image_1 = cv2.bitwise_not(filled_image_1)

# Display the original, inverted, and filled images
plt.subplot(131), plt.imshow(binary_image, cmap='gray')
plt.title('Original Binary Image'), plt.xticks([]), plt.yticks([])

plt.subplot(132), plt.imshow(inverted_image, cmap='gray')
plt.title('Inverted Image'), plt.xticks([]), plt.yticks([])

plt.subplot(133), plt.imshow(filled_image_1, cmap='gray')
plt.title('Filled Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read the binary image

# Threshold the image to ensure it's binary
binary_image = filled_image_1

# Invert the binary image
inverted_image = cv2.bitwise_not(binary_image)

# Create a kernel for dilation
kernel = np.ones((3, 3), np.uint8)

# Dilate the inverted image to fill white holes in the black regions
filled_image_1 = cv2.dilate(inverted_image, kernel, iterations=1)

# Invert the result back to get the final filled image
filled_image_1 = cv2.bitwise_not(filled_image_1)

# Display the original, inverted, and filled images
plt.subplot(131), plt.imshow(binary_image, cmap='gray')
plt.title('Original Binary Image'), plt.xticks([]), plt.yticks([])

plt.subplot(132), plt.imshow(inverted_image, cmap='gray')
plt.title('Inverted Image'), plt.xticks([]), plt.yticks([])

plt.subplot(133), plt.imshow(filled_image_1, cmap='gray')
plt.title('Filled Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read the binary image

# Threshold the image to ensure it's binary
binary_image = filled_image_1

# Invert the binary image
inverted_image = cv2.bitwise_not(binary_image)

# Create a kernel for dilation
kernel = np.ones((3, 3), np.uint8)

# Dilate the inverted image to fill white holes in the black regions
filled_image_1 = cv2.dilate(inverted_image, kernel, iterations=1)

# Invert the result back to get the final filled image
filled_image_1 = cv2.bitwise_not(filled_image_1)

# Display the original, inverted, and filled images
plt.subplot(131), plt.imshow(binary_image, cmap='gray')
plt.title('Original Binary Image'), plt.xticks([]), plt.yticks([])

plt.subplot(132), plt.imshow(inverted_image, cmap='gray')
plt.title('Inverted Image'), plt.xticks([]), plt.yticks([])

plt.subplot(133), plt.imshow(filled_image_1, cmap='gray')
plt.title('Filled Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
binary_image = filled_image_1

inverted_image = cv2.bitwise_not(binary_image)

kernel = np.ones((3, 3), np.uint8)
filled_image_1 = cv2.dilate(inverted_image, kernel, iterations=1)
filled_image_1 = cv2.bitwise_not(filled_image_1)
plt.subplot(131), plt.imshow(binary_image, cmap='gray')
plt.title('Original Binary Image'), plt.xticks([]), plt.yticks([])

plt.subplot(132), plt.imshow(inverted_image, cmap='gray')
plt.title('Inverted Image'), plt.xticks([]), plt.yticks([])

plt.subplot(133), plt.imshow(filled_image_1, cmap='gray')
plt.title('Filled Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read the binary image

# Threshold the image to ensure it's binary
binary_image = filled_image_1

# Invert the binary image
inverted_image = cv2.bitwise_not(binary_image)

# Create a kernel for dilation
kernel = np.ones((3, 3), np.uint8)

# Dilate the inverted image to fill white holes in the black regions
filled_image_1 = cv2.dilate(inverted_image, kernel, iterations=1)

# Invert the result back to get the final filled image
filled_image_1 = cv2.bitwise_not(filled_image_1)

# Display the original, inverted, and filled images
plt.subplot(131), plt.imshow(binary_image, cmap='gray')
plt.title('Original Binary Image'), plt.xticks([]), plt.yticks([])

plt.subplot(132), plt.imshow(inverted_image, cmap='gray')
plt.title('Inverted Image'), plt.xticks([]), plt.yticks([])

plt.subplot(133), plt.imshow(filled_image_1, cmap='gray')
plt.title('Filled Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
imgplot = plt.imshow(filled_image_1)
plt.show()

# %%
import numpy as np

def center_of_mass(binary_image):
    # Get the shape of the image
    print("Image shape:", binary_image.shape)
    image_height, image_width = binary_image.shape

    SumX = 0
    SumY = 0
    num = 0

    for i in range(image_width):
        for j in range(image_height):
            if binary_image[j, i] == 0:
                SumX += i
                SumY += j
                num += 1

    center_x = SumX / num
    center_y = SumY / num

    return center_x, center_y

# Example usage:
# Assuming rect_1 is your binary image
center_x, center_y = center_of_mass(filled_image_1)
print("Center of mass coordinates:", center_x, center_y)

# %%
import cv2

rect_1 = filled_image_1.copy()
hello = rect_1.copy()
cv2.circle(hello, [448, 447], 10, [255, 255, 255], -1)


plt.subplot(131), plt.imshow(hello, cmap='gray')
plt.title('Original Binary Image'), plt.xticks([]), plt.yticks([])

plt.subplot(132), plt.imshow(filled_image_1, cmap='gray')
plt.title('Inverted Image'), plt.xticks([]), plt.yticks([])


plt.show()

# %%
import cv2
import numpy as np


# Get the dimensions of the image
image_height, image_width = binary_image.shape

# Initialize variables to store min and max coordinates
min_x = image_width
max_x = 0
min_y = image_height
max_y = 0

# Get the center of mass coordinates
SumX = 0
SumY = 0
num = 0

for i in range(image_width):
    for j in range(image_height):
        if binary_image[j, i] == 0:  # Assuming black pixels represent the object
            SumX += i
            SumY += j
            num += 1
            # Update min and max coordinates
            min_x = min(min_x, i)
            max_x = max(max_x, i)
            min_y = min(min_y, j)
            max_y = max(max_y, j)

center_x = SumX / num
center_y = SumY / num

ideal_center_x = (min_x+max_x)/2
ideal_center_y = (min_y+max_y)/2

print(binary_image.shape)
print("Center of mass:", center_x, center_y)
print("Min X:", min_x, "Max X:", max_x)
print("Min Y:", min_y, "Max Y:", max_y)
print(ideal_center_x,ideal_center_y)
print(num)

width = max_x
height = max_y
image_with_rectangle = cv2.rectangle(binary_image.copy(), (min_x, min_y), (max_x, max_y), (0, 0, 0), 2)
cv2.circle(image_with_rectangle,[int(ideal_center_x),int(ideal_center_y)],10,[255,255,255],-1)
plt.imshow(image_with_rectangle)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import distance_transform_edt
import cv2
import tensorflow as tf
from collections import deque
import random

class ImageEnvironment:
    def __init__(self, edge_points, initial_com, ideal_com,prev_dist):
        self.edge_points = edge_points
        self.num_points = len(edge_points)
        self.ideal_com = ideal_com
        self.weights = np.ones(self.num_points)  # Initialize weights to 1
        self.com = initial_com  # Initialize COM as [x, y]
        self.prev_dist=prev_dist

    def reset(self):
        """Reset the environment to its initial state."""
        self.weights = np.ones(self.num_points)
        self.com = np.ones(2)

    def update_com(self):
        """Calculate the center of mass (COM) of the edge points."""
        total_weight = np.sum(self.weights)
        if total_weight == 0:
            self.com = np.zeros(2)
        else:
            weighted_sum = np.sum(np.array(self.edge_points) * self.weights[:, np.newaxis], axis=0)
            self.com = weighted_sum / total_weight

    def take_action(self, point_idx, com_color='red'):
        """Take an action to add weight to a specified edge point."""
        self.weights[point_idx] += 1
        self.update_com()
        # Check if the added point already exists in edge_points
        added_point = self.edge_points[point_idx]
        if added_point not in self.edge_points:
            self.edge_points.append(added_point)  # Add the point to edge_points
            self.num_points += 1  # Update the number of points
            self.weights = np.append(self.weights, [1])  # Add a default weight for the new point
        self.visualize(point_idx, com_color)  # Visualize the environment after taking the action
        return self.get_state()  # Return the next state after taking the action

    def get_reward(self):
        """Calculate the reward based on the change in Manhattan distance of the COM from the ideal position."""
        # print("Ideal COM ",self.ideal_com)
        # print("Actual COM ",self.com)
        # dist = np.sqrt((new_x-ideal_center_x)**2+(new_y-ideal_center_y)**2) * (1/(dump_points[i][0]))
        current_distance = np.linalg.norm(self.com - self.ideal_com, ord=1)
        if current_distance < self.prev_dist:
            # print("Current distance = ",current_distance)
            # print("Prev distance = ",np.linalg.norm(self.ideal_com, ord=1))
            reward = abs(1000/current_distance)  # Reward for moving towards the ideal position
        else:
            reward = -abs(np.log(current_distance))  # Penalty for moving away from the ideal position

        # print("Distance bw ideal and actual COM = ",current_distance)
        # print("Reward = ", reward)
        self.prev_dist = current_distance
        return reward

    def get_state(self):
        """Return the current state of the environment."""
        return self.weights.copy(), self.com

    def visualize(self, point_idx, com_color='red'):
        """Visualize the environment with the edge points, weights, and the current center of mass."""
        plt.figure(figsize=(8, 6))
        plt.scatter([p[0] for p in self.edge_points], [p[1] for p in self.edge_points], color='black', label='Edge Points')
        plt.scatter(self.com[0], self.com[1], color=com_color, marker='o', label='Updated COM')  # Plot updated COM
        plt.scatter(self.ideal_com[0], self.ideal_com[1], color='blue', marker='*', label='Ideal COM')  # Plot ideal COM
        plt.scatter(self.edge_points[point_idx][0], self.edge_points[point_idx][1], color='red', marker='s', label='Added Weight')  # Plot point where weight is added
        plt.annotate(f'({self.edge_points[point_idx][0]}, {self.edge_points[point_idx][1]})', (self.edge_points[point_idx][0], self.edge_points[point_idx][1] + 10), color='red')  # Annotate point where weight is added
        plt.text(self.com[0], self.com[1] + 10, f'Updated COM: ({self.com[0]}, {self.com[1]})', ha='center', color=com_color)  # Print updated COM
        plt.xlabel('X Coordinate')
        plt.ylabel('Y Coordinate')
        plt.title('Image Environment')
        plt.legend()
        plt.grid(True)
        plt.gca().set_aspect('equal')  # Set aspect ratio to equal to maintain correct proportions
        plt.gca().invert_yaxis()  # Reverse the y-axis
        plt.show()

# Deep Q-Network (DQN)
class DQN(tf.keras.Model):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.dense1 = tf.keras.layers.Dense(64, activation='relu')
        self.dense2 = tf.keras.layers.Dense(64, activation='relu')
        self.output_layer = tf.keras.layers.Dense(action_size,activation='sigmoid')

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        return self.output_layer(x)

# Replay Buffer
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def add(self, experience):
        self.buffer.append(experience)

    def sample(self, batch_size):
        return random.sample(self.buffer, batch_size)

# DQN Agent
class DQNAgent:
    def __init__(self, state_size, action_size, epsilon=1, epsilon_decay=0.990, epsilon_min=0.01, gamma=0.95, batch_size=32):
        self.state_size = state_size
        self.action_size = action_size
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        self.gamma = gamma
        self.batch_size = batch_size
        self.model = DQN(state_size, action_size)
        self.target_model = DQN(state_size, action_size)
        self.target_model.set_weights(self.model.get_weights())
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
        self.replay_buffer = ReplayBuffer(capacity=10000000)

    def select_action(self, state):
        weights, com = state
        flat_state = np.concatenate((weights, com))
        print(self.epsilon)
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        q_values = self.model.predict(np.expand_dims(flat_state, axis=0))[0]
        # print(q_values)
        return np.argmax(q_values)

    def train(self):
        print(len(self.replay_buffer.buffer))
        if len(self.replay_buffer.buffer) < self.batch_size:
            return
        batch = self.replay_buffer.sample(self.batch_size)
        states, actions, rewards, next_states = zip(*batch)
        # Concatenate weights and COM tuples into flat arrays
        states = np.concatenate([np.concatenate(state) for state in states], axis=0).reshape(self.batch_size, -1)
        next_states = np.concatenate([np.concatenate(next_state) for next_state in next_states], axis=0).reshape(self.batch_size, -1)
        actions = np.array(actions)
        rewards = np.array(rewards)
        target_q_values = self.target_model.predict(next_states)
        target_q_values = rewards + self.gamma * np.amax(target_q_values, axis=1)
        q_values = self.model.predict(states)
        q_values[np.arange(self.batch_size), actions] = target_q_values
        with tf.GradientTape() as tape:
            loss = tf.reduce_mean(tf.square(q_values - self.model(states)))
        grads = tape.gradient(loss, self.model.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))

    def update_target_network(self):
        self.target_model.set_weights(self.model.get_weights())

# Load the image (replace 'filled_image_1' with your image path)
image = filled_image_1

# Detect edges using Canny edge detection
edges = cv2.Canny(image, 100, 200)

# Find contours from the edges
contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Sample points along the contours
edge_points = []
for contour in contours:
    points = contour[:, 0, :]
    edge_points.extend(points)

# Convert edge_points to list of tuples (x, y)
edge_points = [(p[0], p[1]) for p in edge_points]

# Define the initial and ideal COM positions (replace with your desired positions)
initial_com = np.array([507, 396])
ideal_com = np.array([457.5 ,389.5])

# Create the environment
env = ImageEnvironment(edge_points, initial_com, ideal_com,prev_dist=1e9+7)

state_size = env.num_points * 2  # Number of edge points * 2 (x and y coordinates)
action_size = env.num_points  # Number of edge points (actions correspond to selecting which pixel to add weight to)

# Create the DQN agent
agent = DQNAgent(state_size, action_size)

distances = []

# Train the agent
episodes = 250
for episode in range(episodes):
    state = env.get_state()
    c = 0
    done = False
    while not done:
        c += 1
        action = agent.select_action(state)
        next_state = env.take_action(action)  # Take the selected action
        reward = env.get_reward()
        agent.replay_buffer.add((state, action, reward, next_state))
        agent.train()
        agent.update_target_network()
        state = next_state
        if c > 50:
            break
        if done:
            break
        # Calculate the distance between the ideal COM and the current COM
        current_distance = np.linalg.norm(env.com - env.ideal_com, ord=1)
        distances.append(current_distance)

    # Decay epsilon
    if agent.epsilon > agent.epsilon_min:
        agent.epsilon *= agent.epsilon_decay
    
    agent.replay_buffer.buffer.clear()


# main_model_weights = agent.model.get_weights()
# target_model_weights = agent.target_model.get_weights()

# print("Main Model Weights:")
# for layer_weights in main_model_weights:
#     print(layer_weights.shape)  # Print the shape of each layer's weights

# print("\nTarget Model Weights:")
# for layer_weights in target_model_weights:
#     print(layer_weights.shape)  # Print the shape of each layer's weights
    

# Plot the distance between the ideal COM and the current COM over iterations
plt.figure(figsize=(8, 6))
plt.plot(range(len(distances)), distances, marker='o', linestyle='-')
plt.xlabel('Iterations')
plt.ylabel('Distance between Ideal COM and Current COM')
plt.title('Distance between Ideal COM and Current COM over Iterations')
plt.grid(True)
plt.show()

# Test the agent after training (optional)
# You can add code here to test the trained agent on the environment

# %%
print(len(edge_points))

# %%
import tensorflow as tf
devices = tf.config.list_physical_devices()
print("\nDevices: ", devices)

gpus = tf.config.list_physical_devices('GPU')
if gpus:
  details = tf.config.experimental.get_device_details(gpus[0])
  print("GPU details: ", details)

# %%
# !pip install --upgrade tensorflow-metal

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import distance_transform_edt
import cv2
import tensorflow as tf
from collections import deque
import random

class ImageEnvironment:
    def __init__(self, edge_points, initial_com, ideal_com,prev_dist):
        self.edge_points = edge_points
        self.num_points = len(edge_points)
        self.ideal_com = ideal_com
        self.weights = np.ones(self.num_points)  # Initialize weights to 1
        self.com = initial_com  # Initialize COM as [x, y]
        self.prev_dist=prev_dist

    def reset(self):
        """Reset the environment to its initial state."""
        self.weights = np.ones(self.num_points)
        self.com = np.ones(2)

    def update_com(self):
        """Calculate the center of mass (COM) of the edge points."""
        total_weight = np.sum(self.weights)
        if total_weight == 0:
            self.com = np.zeros(2)
        else:
            weighted_sum = np.sum(np.array(self.edge_points) * self.weights[:, np.newaxis], axis=0)
            self.com = weighted_sum / total_weight

    def take_action(self, point_idx, com_color='red'):
        """Take an action to add weight to a specified edge point."""
        self.weights[point_idx] += 1
        self.update_com()
        # Check if the added point already exists in edge_points
        added_point = self.edge_points[point_idx]
        if added_point not in self.edge_points:
            self.edge_points.append(added_point)  # Add the point to edge_points
            self.num_points += 1  # Update the number of points
            self.weights = np.append(self.weights, [1])  # Add a default weight for the new point
        self.visualize(point_idx, com_color)  # Visualize the environment after taking the action
        return self.get_state()  # Return the next state after taking the action

    def get_reward(self):
        """Calculate the reward based on the change in Manhattan distance of the COM from the ideal position."""
        # print("Ideal COM ",self.ideal_com)
        # print("Actual COM ",self.com)
        # dist = np.sqrt((new_x-ideal_center_x)**2+(new_y-ideal_center_y)**2) * (1/(dump_points[i][0]))
        current_distance = np.linalg.norm(self.com - self.ideal_com, ord=1)
        if current_distance < self.prev_dist:
            # print("Current distance = ",current_distance)
            # print("Prev distance = ",np.linalg.norm(self.ideal_com, ord=1))
            reward = abs(1000/current_distance)  # Reward for moving towards the ideal position
        else:
            reward = -abs(np.log(current_distance))  # Penalty for moving away from the ideal position

        # print("Distance bw ideal and actual COM = ",current_distance)
        # print("Reward = ", reward)
        self.prev_dist = current_distance
        return reward

    def get_state(self):
        """Return the current state of the environment."""
        return self.weights.copy(), self.com

    def visualize(self, point_idx, com_color='red'):
        """Visualize the environment with the edge points, weights, and the current center of mass."""
        plt.figure(figsize=(8, 6))
        plt.scatter([p[0] for p in self.edge_points], [p[1] for p in self.edge_points], color='black', label='Edge Points')
        plt.scatter(self.com[0], self.com[1], color=com_color, marker='o', label='Updated COM')  # Plot updated COM
        plt.scatter(self.ideal_com[0], self.ideal_com[1], color='blue', marker='*', label='Ideal COM')  # Plot ideal COM
        plt.scatter(self.edge_points[point_idx][0], self.edge_points[point_idx][1], color='red', marker='s', label='Added Weight')  # Plot point where weight is added
        plt.annotate(f'({self.edge_points[point_idx][0]}, {self.edge_points[point_idx][1]})', (self.edge_points[point_idx][0], self.edge_points[point_idx][1] + 10), color='red')  # Annotate point where weight is added
        plt.text(self.com[0], self.com[1] + 10, f'Updated COM: ({self.com[0]}, {self.com[1]})', ha='center', color=com_color)  # Print updated COM
        plt.xlabel('X Coordinate')
        plt.ylabel('Y Coordinate')
        plt.title('Image Environment')
        plt.legend()
        plt.grid(True)
        plt.gca().set_aspect('equal')  # Set aspect ratio to equal to maintain correct proportions
        plt.gca().invert_yaxis()  # Reverse the y-axis
        plt.show()

# Deep Q-Network (DQN)
class DQN(tf.keras.Model):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.dense1 = tf.keras.layers.Dense(64, activation='relu')
        self.dense2 = tf.keras.layers.Dense(64, activation='relu')
        self.output_layer = tf.keras.layers.Dense(action_size,activation='sigmoid')

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        return self.output_layer(x)

# Replay Buffer
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def add(self, experience):
        self.buffer.append(experience)

    def sample(self, batch_size):
        return random.sample(self.buffer, batch_size)

# DQN Agent
class DQNAgent:
    def __init__(self, state_size, action_size, epsilon=1, epsilon_decay=0.990, epsilon_min=0.01, gamma=0.95, batch_size=32):
        self.state_size = state_size
        self.action_size = action_size
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        self.gamma = gamma
        self.batch_size = batch_size
        self.model = DQN(state_size, action_size)
        self.target_model = DQN(state_size, action_size)
        self.target_model.set_weights(self.model.get_weights())
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
        self.replay_buffer = ReplayBuffer(capacity=10000000)

    def select_action(self, state):
        weights, com = state
        flat_state = np.concatenate((weights, com))
        print(self.epsilon)
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        q_values = self.model.predict(np.expand_dims(flat_state, axis=0))[0]
        # print(q_values)
        return np.argmax(q_values)

    def train(self):
        print(len(self.replay_buffer.buffer))
        if len(self.replay_buffer.buffer) < self.batch_size:
            return
        batch = self.replay_buffer.sample(self.batch_size)
        states, actions, rewards, next_states = zip(*batch)
        # Concatenate weights and COM tuples into flat arrays
        states = np.concatenate([np.concatenate(state) for state in states], axis=0).reshape(self.batch_size, -1)
        next_states = np.concatenate([np.concatenate(next_state) for next_state in next_states], axis=0).reshape(self.batch_size, -1)
        actions = np.array(actions)
        rewards = np.array(rewards)
        target_q_values = self.target_model.predict(next_states)
        target_q_values = rewards + self.gamma * np.amax(target_q_values, axis=1)
        q_values = self.model.predict(states)
        q_values[np.arange(self.batch_size), actions] = target_q_values
        with tf.GradientTape() as tape:
            loss = tf.reduce_mean(tf.square(q_values - self.model(states)))
        grads = tape.gradient(loss, self.model.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))

    def update_target_network(self):
        self.target_model.set_weights(self.model.get_weights())

# Load the image (replace 'filled_image_1' with your image path)
image = filled_image_1

# Detect edges using Canny edge detection
edges = cv2.Canny(image, 100, 200)

# Find contours from the edges
contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Sample points along the contours
edge_points = []
for contour in contours:
    points = contour[:, 0, :]
    edge_points.extend(points)

# Convert edge_points to list of tuples (x, y)
edge_points = [(p[0], p[1]) for p in edge_points]

# Define the initial and ideal COM positions (replace with your desired positions)
initial_com = np.array([507, 396])
ideal_com = np.array([457.5 ,389.5])

# Create the environment
env = ImageEnvironment(edge_points, initial_com, ideal_com,prev_dist=1e9+7)

state_size = env.num_points * 2  # Number of edge points * 2 (x and y coordinates)
action_size = env.num_points  # Number of edge points (actions correspond to selecting which pixel to add weight to)

# Create the DQN agent
agent = DQNAgent(state_size, action_size)

distances = []

# Train the agent
episodes = 250
for episode in range(episodes):
    state = env.get_state()
    c = 0
    done = False
    while not done:
        c += 1
        action = agent.select_action(state)
        next_state = env.take_action(action)  # Take the selected action
        reward = env.get_reward()
        agent.replay_buffer.add((state, action, reward, next_state))
        agent.train()
        agent.update_target_network()
        state = next_state
        if c > 50:
            break
        if done:
            break
        # Calculate the distance between the ideal COM and the current COM
        current_distance = np.linalg.norm(env.com - env.ideal_com, ord=1)
        distances.append(current_distance)

    # Decay epsilon
    if agent.epsilon > agent.epsilon_min:
        agent.epsilon *= agent.epsilon_decay
    
    agent.replay_buffer.buffer.clear()


# main_model_weights = agent.model.get_weights()
# target_model_weights = agent.target_model.get_weights()

# print("Main Model Weights:")
# for layer_weights in main_model_weights:
#     print(layer_weights.shape)  # Print the shape of each layer's weights

# print("\nTarget Model Weights:")
# for layer_weights in target_model_weights:
#     print(layer_weights.shape)  # Print the shape of each layer's weights
    

# Plot the distance between the ideal COM and the current COM over iterations
plt.figure(figsize=(8, 6))
plt.plot(range(len(distances)), distances, marker='o', linestyle='-')
plt.xlabel('Iterations')
plt.ylabel('Distance between Ideal COM and Current COM')
plt.title('Distance between Ideal COM and Current COM over Iterations')
plt.grid(True)
plt.show()

# Test the agent after training (optional)
# You can add code here to test the trained agent on the environment

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import distance_transform_edt
import cv2
import tensorflow as tf
from collections import deque
import random

class ImageEnvironment:
    def __init__(self, edge_points, initial_com, ideal_com,prev_dist):
        self.edge_points = edge_points
        self.num_points = len(edge_points)
        self.ideal_com = ideal_com
        self.weights = np.ones(self.num_points)  # Initialize weights to 1
        self.com = initial_com  # Initialize COM as [x, y]
        self.prev_dist=prev_dist

    def reset(self):
        """Reset the environment to its initial state."""
        self.weights = np.ones(self.num_points)
        self.com = np.ones(2)

    def update_com(self):
        """Calculate the center of mass (COM) of the edge points."""
        total_weight = np.sum(self.weights)
        if total_weight == 0:
            self.com = np.zeros(2)
        else:
            weighted_sum = np.sum(np.array(self.edge_points) * self.weights[:, np.newaxis], axis=0)
            self.com = weighted_sum / total_weight

    def take_action(self, point_idx, com_color='red'):
        """Take an action to add weight to a specified edge point."""
        self.weights[point_idx] += 1
        self.update_com()
        # Check if the added point already exists in edge_points
        added_point = self.edge_points[point_idx]
        if added_point not in self.edge_points:
            self.edge_points.append(added_point)  # Add the point to edge_points
            self.num_points += 1  # Update the number of points
            self.weights = np.append(self.weights, [1])  # Add a default weight for the new point
        self.visualize(point_idx, com_color)  # Visualize the environment after taking the action
        return self.get_state()  # Return the next state after taking the action

    def get_reward(self):
        """Calculate the reward based on the change in Manhattan distance of the COM from the ideal position."""
        # print("Ideal COM ",self.ideal_com)
        # print("Actual COM ",self.com)
        # dist = np.sqrt((new_x-ideal_center_x)**2+(new_y-ideal_center_y)**2) * (1/(dump_points[i][0]))
        current_distance = np.linalg.norm(self.com - self.ideal_com, ord=1)
        print("distance: ",current_distance)
        if current_distance < self.prev_dist:
            # print("Current distance = ",current_distance)
            # print("Prev distance = ",np.linalg.norm(self.ideal_com, ord=1))
            reward = abs(1000/current_distance)  # Reward for moving towards the ideal position
        else:
            reward = -abs(np.log(current_distance))  # Penalty for moving away from the ideal position

        # print("Distance bw ideal and actual COM = ",current_distance)
        # print("Reward = ", reward)
        self.prev_dist = min(current_distance,self.prev_dist)
        print("Reward:",reward)
        return reward

    def get_state(self):
        """Return the current state of the environment."""
        return self.weights.copy(), self.com

    def visualize(self, point_idx, com_color='red'):
        """Visualize the environment with the edge points, weights, and the current center of mass."""
        plt.figure(figsize=(8, 6))
        plt.scatter([p[0] for p in self.edge_points], [p[1] for p in self.edge_points], color='black', label='Edge Points')
        plt.scatter(self.com[0], self.com[1], color=com_color, marker='o', label='Updated COM')  # Plot updated COM
        plt.scatter(self.ideal_com[0], self.ideal_com[1], color='blue', marker='*', label='Ideal COM')  # Plot ideal COM
        plt.scatter(self.edge_points[point_idx][0], self.edge_points[point_idx][1], color='red', marker='s', label='Added Weight')  # Plot point where weight is added
        plt.annotate(f'({self.edge_points[point_idx][0]}, {self.edge_points[point_idx][1]})', (self.edge_points[point_idx][0], self.edge_points[point_idx][1] + 10), color='red')  # Annotate point where weight is added
        plt.text(self.com[0], self.com[1] + 10, f'Updated COM: ({self.com[0]}, {self.com[1]})', ha='center', color=com_color)  # Print updated COM
        plt.xlabel('X Coordinate')
        plt.ylabel('Y Coordinate')
        plt.title('Image Environment')
        plt.legend()
        plt.grid(True)
        plt.gca().set_aspect('equal')  # Set aspect ratio to equal to maintain correct proportions
        plt.gca().invert_yaxis()  # Reverse the y-axis
        plt.show()

# Deep Q-Network (DQN)
class DQN(tf.keras.Model):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.dense1 = tf.keras.layers.Dense(64, activation='relu')
        self.dense2 = tf.keras.layers.Dense(64, activation='relu')
        self.output_layer = tf.keras.layers.Dense(action_size,activation='sigmoid')

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        return self.output_layer(x)

# Replay Buffer
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def add(self, experience):
        self.buffer.append(experience)

    def sample(self, batch_size):
        return random.sample(self.buffer, batch_size)

# DQN Agent
class DQNAgent:
    def __init__(self, state_size, action_size, epsilon=1, epsilon_decay=0.990, epsilon_min=0.01, gamma=0.95, batch_size=128):
        self.state_size = state_size
        self.action_size = action_size
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        self.gamma = gamma
        self.batch_size = batch_size
        self.model = DQN(state_size, action_size)
        self.target_model = DQN(state_size, action_size)
        self.target_model.set_weights(self.model.get_weights())
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
        self.replay_buffer = ReplayBuffer(capacity=10000000)
        self.model.compile(optimizer=self.optimizer, loss='mse')

    def select_action(self, state):
        weights, com = state
        flat_state = np.concatenate((weights, com))
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        q_values = self.model.predict(np.expand_dims(flat_state, axis=0))[0]
        # print(q_values)
        return np.argmax(q_values)

    def train(self):
        if len(self.replay_buffer.buffer) < self.batch_size:
            return

        # Sample a batch from the replay buffer
        batch = self.replay_buffer.sample(self.batch_size)
        states, actions, rewards, next_states = zip(*batch)

        # Concatenate states and next_states into flat arrays
        states = np.concatenate([np.concatenate(state) for state in states], axis=0).reshape(self.batch_size, -1)
        next_states = np.concatenate([np.concatenate(next_state) for next_state in next_states], axis=0).reshape(self.batch_size, -1)

        actions = np.array(actions)
        rewards = np.array(rewards)

        # Compute target Q values
        target_q_values = self.target_model.predict(next_states)
        target_q_values = rewards + self.gamma * np.amax(target_q_values, axis=1)

        # Compute Q values for the current states
        q_values = self.model.predict(states)
        q_values[np.arange(self.batch_size), actions] = target_q_values

        # Use the replay buffer to generate training data
        x_train = states
        y_train = q_values

        # Train the model using model.fit()
        self.model.fit(x_train, y_train, verbose=0)

    def update_target_network(self):
        self.target_model.set_weights(self.model.get_weights())

# Load the image (replace 'filled_image_1' with your image path)
image = filled_image_1

# Detect edges using Canny edge detection
edges = cv2.Canny(image, 100, 200)

# Find contours from the edges
contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Sample points along the contours
edge_points = []
for contour in contours:
    points = contour[:, 0, :]
    edge_points.extend(points)

# Convert edge_points to list of tuples (x, y)
edge_points = [(p[0], p[1]) for p in edge_points]

# Define the initial and ideal COM positions (replace with your desired positions)
initial_com = np.array([304,303])
ideal_com = np.array([307.5,263.5])

# Create the environment
env = ImageEnvironment(edge_points, initial_com, ideal_com,prev_dist=1e9+7)

state_size = env.num_points * 2  # Number of edge points * 2 (x and y coordinates)
action_size = env.num_points  # Number of edge points (actions correspond to selecting which pixel to add weight to)

# Create the DQN agent
agent = DQNAgent(state_size, action_size)

distances = []

# Train the agent
episodes = 100
for episode in range(episodes):
    state = env.get_state()
    c = 0
    done = False
    print("Episode:",episode)
    while not done:
        c += 1
        action = agent.select_action(state)
        next_state = env.take_action(action)  # Take the selected action
        reward = env.get_reward()
        agent.replay_buffer.add((state, action, reward, next_state))
        agent.train()
        agent.update_target_network()
        state = next_state
        if c > 200:
            break
        if done:
            break
        # Calculate the distance between the ideal COM and the current COM
        current_distance = np.linalg.norm(env.com - env.ideal_com, ord=1)
        distances.append(current_distance)

    # Decay epsilon
    if agent.epsilon > agent.epsilon_min:
        agent.epsilon *= agent.epsilon_decay
    
    agent.replay_buffer.buffer.clear()


# main_model_weights = agent.model.get_weights()
# target_model_weights = agent.target_model.get_weights()

# print("Main Model Weights:")
# for layer_weights in main_model_weights:
#     print(layer_weights.shape)  # Print the shape of each layer's weights

# print("\nTarget Model Weights:")
# for layer_weights in target_model_weights:
#     print(layer_weights.shape)  # Print the shape of each layer's weights
    

# Plot the distance between the ideal COM and the current COM over iterations
plt.figure(figsize=(8, 6))
plt.plot(range(len(distances)), distances, marker='o', linestyle='-')
plt.xlabel('Iterations')
plt.ylabel('Distance between Ideal COM and Current COM')
plt.title('Distance between Ideal COM and Current COM over Iterations')
plt.grid(True)
plt.show()

# Test the agent after training (optional)
# You can add code here to test the trained agent on the environment

# %% [markdown]
# # 3d environment

# %%
class ImageEnvironment3D:
    def __init__(self, edge_points, initial_com, ideal_com, prev_dist):
        self.edge_points = edge_points
        self.num_points = len(edge_points)
        self.ideal_com = ideal_com
        self.weights = np.ones(self.num_points)  # Initialize weights to 1
        self.com = initial_com  # Initialize COM as [x, y, z]
        self.prev_dist = prev_dist

    def reset(self):
        """Reset the environment to its initial state."""
        self.weights = np.ones(self.num_points)
        self.com = np.ones(3)

    def update_com(self):
        """Calculate the center of mass (COM) of the edge points in 3D."""
        total_weight = np.sum(self.weights)
        if total_weight == 0:
            self.com = np.zeros(3)
        else:
            weighted_sum = np.sum(np.array(self.edge_points) * self.weights[:, np.newaxis], axis=0)
            self.com = weighted_sum / total_weight

    def take_action(self, point_idx, com_color='red'):
        """Take an action to add weight to a specified 3D edge point."""
        self.weights[point_idx] += 1
        self.update_com()
        added_point = self.edge_points[point_idx]
        if added_point not in self.edge_points:
            self.edge_points.append(added_point)
            self.num_points += 1
            self.weights = np.append(self.weights, [1])
        self.visualize(point_idx, com_color)
        return self.get_state()

    def get_reward(self):
        """Calculate the reward based on the change in Manhattan distance of the COM from the ideal position."""
        current_distance = np.linalg.norm(self.com - self.ideal_com, ord=1)
        if current_distance < self.prev_dist:
            reward = abs(1000/current_distance)  # Reward for moving towards the ideal position
        else:
            reward = -abs(np.log(current_distance))  # Penalty for moving away from the ideal position
        self.prev_dist = current_distance
        return reward

    def get_state(self):
        """Return the current state of the environment."""
        return self.weights.copy(), self.com

    def visualize(self, point_idx, com_color='red'):
        """Visualize the environment in 3D."""
        fig = plt.figure(figsize=(8, 6))
        ax = fig.add_subplot(111, projection='3d')
        ax.scatter([p[0] for p in self.edge_points], [p[1] for p in self.edge_points], [p[2] for p in self.edge_points], color='black', label='Edge Points')
        ax.scatter(self.com[0], self.com[1], self.com[2], color=com_color, marker='o', label='Updated COM')
        ax.scatter(self.ideal_com[0], self.ideal_com[1], self.ideal_com[2], color='blue', marker='*', label='Ideal COM')
        ax.scatter(self.edge_points[point_idx][0], self.edge_points[point_idx][1], self.edge_points[point_idx][2], color='red', marker='s', label='Added Weight')
        ax.set_xlabel('X Coordinate')
        ax.set_ylabel('Y Coordinate')
        ax.set_zlabel('Z Coordinate')
        ax.set_title('3D Image Environment')
        plt.legend()
        plt.grid(True)
        plt.show()
